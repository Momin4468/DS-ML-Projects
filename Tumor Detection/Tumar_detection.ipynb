# %% [markdown]
# ## Exploratory data analysis

# %%
import numpy as np
from PIL import Image, ImageDraw
import matplotlib.pylab as plt
# fix random seed
np.random.seed(2019)

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import pandas as pd
import os
from tqdm import tqdm

# %% [markdown]
# ## Load DataSet

# %%
path = 'C:/Users/z2m09/Desktop/BT/train/images'

# %%
data = [os.path.join(path,x) for x in os.listdir(path)]

# %%
images = [data[x] for x in range(len(data)) if data[x].endswith('.jpg')]
labels = [data[x] for x in range(len(data)) if data[x].endswith('.txt')]

# %%
plt.imshow(cv2.cvtColor(cv2.imread(images[0]),cv2.COLOR_BGR2RGB))

# %% [markdown]
# ## Data set -1  Indexing

# %%
df = pd.DataFrame(columns=['image_name','object','x_cen','y_cen','w','h'])
i=0
for id in tqdm(images):
    label = open(id[:-4]+'.txt','r') 
    a = label.read()
    label.close()
    label = a.split('\n')
    cleaned_label = label[:-1]
    
    for name in cleaned_label:
        ind_label = name.split(' ')
        df.loc[i,'image_name'] = id[39:]
        df.loc[i,'object'] = int(ind_label[0])
        df.loc[i,'x_cen'] = float(ind_label[1])
        df.loc[i,'y_cen'] = float(ind_label[2])
        df.loc[i,'w'] = float(ind_label[3])
        df.loc[i,'h'] = float(ind_label[4])
        i += 1
# Out:
# 100%|██████████| 6930/6930 [02:20<00:00, 49.50it/s]

# %%
df.head()
# Out:
#                                           image_name object     x_cen  \
# 0  volume_100_slice_42_jpg.rf.aa9204d61a24f8d7c56...      0  0.489583
# 1  volume_100_slice_45_jpg.rf.4066dffd96c960dae2c...      0  0.489583
# 2  volume_100_slice_45_jpg.rf.4066dffd96c960dae2c...      1  0.579167
# 3  volume_100_slice_46_jpg.rf.4a128ec426c1602d10b...      0    0.4875
# 4  volume_100_slice_46_jpg.rf.4a128ec426c1602d10b...      1   0.58125
#
#       y_cen         w         h
# 0  0.266667    0.0125  0.008333
# 1   0.28125  0.054167    0.0625
# 2  0.322917  0.216667    0.0875
# 3  0.279167  0.091667  0.083333
# 4  0.320833  0.229167  0.091667

# %% [markdown]
# ## Data set -2  Indexing

# %%
column_name = ['filename', 'width', 'height', 'class', 'xmin', 'ymin', 'xmax', 'ymax']
pascal_voc = pd.DataFrame(columns=column_name)
for i in tqdm(range(len(df))):
    
    pascal_voc.loc[i,'filename'] = df.loc[i,'image_name']
    pascal_voc.loc[i,'width'] = 240
    pascal_voc.loc[i,'height']= 240  
    if df.loc[i,'object'] == 0:    
        pascal_voc.loc[i,'class'] = 'Primary'
    elif df.loc[i,'object'] == 1:
        pascal_voc.loc[i,'class'] = '2nd Stage'
    else:
        pascal_voc.loc[i,'class'] = '3rd Stage'
    pascal_voc.loc[i,'xmin']  = int((df.loc[i,'x_cen'] - df.loc[i,'w']/2)*240)
    pascal_voc.loc[i,'ymin']  = int((df.loc[i,'y_cen'] - df.loc[i,'h']/2)*240)
    pascal_voc.loc[i,'xmax']  = int((df.loc[i,'x_cen'] + df.loc[i,'w']/2)*240)
    pascal_voc.loc[i,'ymax']  = int((df.loc[i,'y_cen'] + df.loc[i,'h']/2)*240)
# Out:
# 100%|██████████| 8366/8366 [00:25<00:00, 329.58it/s]

# %%
pascal_voc.head()
# Out:
#                                             filename width height      class  \
# 0  volume_100_slice_42_jpg.rf.aa9204d61a24f8d7c56...   240    240    Primary
# 1  volume_100_slice_45_jpg.rf.4066dffd96c960dae2c...   240    240    Primary
# 2  volume_100_slice_45_jpg.rf.4066dffd96c960dae2c...   240    240  2nd Stage
# 3  volume_100_slice_46_jpg.rf.4a128ec426c1602d10b...   240    240    Primary
# 4  volume_100_slice_46_jpg.rf.4a128ec426c1602d10b...   240    240  2nd Stage
#
#   xmin ymin xmax ymax
# 0  116   63  118   65
# 1  110   60  123   75
# 2  113   67  165   88
# 3  106   57  128   77
# 4  112   66  167   88

# %% [markdown]
# ## Insert the 'id' column at the beginning of the DataFrame

# %%
import pandas as pd

id_values = list(range(1, len(df) + 1))

# Insert the 'id' column at the beginning of the DataFrame
df.insert(0, 'id', id_values)

# Display the updated DataFrame
df.head()
# Out:
#    id                                         image_name object     x_cen  \
# 0   1  volume_100_slice_42_jpg.rf.aa9204d61a24f8d7c56...      0  0.489583
# 1   2  volume_100_slice_45_jpg.rf.4066dffd96c960dae2c...      0  0.489583
# 2   3  volume_100_slice_45_jpg.rf.4066dffd96c960dae2c...      1  0.579167
# 3   4  volume_100_slice_46_jpg.rf.4a128ec426c1602d10b...      0    0.4875
# 4   5  volume_100_slice_46_jpg.rf.4a128ec426c1602d10b...      1   0.58125
#
#       y_cen         w         h
# 0  0.266667    0.0125  0.008333
# 1   0.28125  0.054167    0.0625
# 2  0.322917  0.216667    0.0875
# 3  0.279167  0.091667  0.083333
# 4  0.320833  0.229167  0.091667

# %% [markdown]
# ## Insert the 'id' column at the beginning of the DataFrame

# %%
id_values = list(range(1, len(pascal_voc) + 1))

pascal_voc.insert(0, 'id', id_values)

pascal_voc.head()
# Out:
#    id                                           filename width height  \
# 0   1  volume_100_slice_42_jpg.rf.aa9204d61a24f8d7c56...   240    240
# 1   2  volume_100_slice_45_jpg.rf.4066dffd96c960dae2c...   240    240
# 2   3  volume_100_slice_45_jpg.rf.4066dffd96c960dae2c...   240    240
# 3   4  volume_100_slice_46_jpg.rf.4a128ec426c1602d10b...   240    240
# 4   5  volume_100_slice_46_jpg.rf.4a128ec426c1602d10b...   240    240
#
#        class xmin ymin xmax ymax
# 0    Primary  116   63  118   65
# 1    Primary  110   60  123   75
# 2  2nd Stage  113   67  165   88
# 3    Primary  106   57  128   77
# 4  2nd Stage  112   66  167   88

# %% [markdown]
# ##  Sample images with the tumar  bounding box

# %%
any_index_number = 1000  # Change this number for different images
image_filename = pascal_voc.loc[any_index_number, 'filename']
test_df = pascal_voc[pascal_voc['filename']==pascal_voc.loc[any_index_number,'filename']].reset_index(drop=True)

if not os.path.isfile(os.path.join(path, image_filename)):
    print(f"Error: File '{image_filename}' does not exist at '{os.path.join(path, image_filename)}'")
else:
    test_img = cv2.cvtColor(cv2.imread(os.path.join(path, image_filename)), cv2.COLOR_BGR2RGB)
    for i in range(len(test_df)):
        rec = cv2.rectangle(test_img, (test_df.loc[i,'xmin'],test_df.loc[i,'ymin']), (test_df.loc[i,'xmax'],test_df.loc[i,'ymax']), (255,0,0), 1, 1) 
        text = cv2.putText(rec, test_df.loc[i,'class'], (test_df.loc[i,'xmin']-50,test_df.loc[i,'ymin']+5), cv2.FONT_HERSHEY_SIMPLEX,.3, (255,255,0), 1, cv2.LINE_AA)

plt.figure(figsize=(8,8))    
plt.imshow(text)
plt.axis('off')
plt.show()

# %% [markdown]
# ## Data transformation for object detection
# ### In object detection tasks, when we perform such transformations on images, we also need
# to update the labels. For instance, when we flip an image horizontally, the location of
# objects in the image will change. While torchvision.transforms provides utility
# functions for image transformations, we need to build our own functions for updating the
# labels. In this recipe, we will develop a pipeline for transforming images and labels in
# single-object detection. We will develop horizontal flipping, vertical flipping, translation,
# and resizing. You can then add more transformations to the pipeline as you need.

# %% [markdown]
# ### create a data transformation pipeline for single-object detection:
# 1. First, we will define a helper function to resize images

# %%
import torchvision.transforms.functional as TF


def resize_img_label(image,label=(0.,0.),target_size=(240,240)):
    w_orig,h_orig = image.size
    w_target,h_target = target_size
    cx, cy= label
    image_new = TF.resize(image,target_size)
    label_new= cx/w_orig*w_target, cy/h_orig*h_target
    return image_new,label_new

# %% [markdown]
# ###  Rescal an image using the preceding function:

# %%
def rescale_label(a,b):
    div = [ai*bi for ai,bi in zip(a,b)]
    return div

# %% [markdown]
# ## Define a helper function to randomly flip images horizontally

# %%
def random_hflip(image,label):
    w,h=image.size
    x,y=label
    image = TF.hflip(image)
    label = w-x, y
    return image,label

# %% [markdown]
# ##  Define a function to randomly flip images vertically

# %%
def random_vflip(image,label):
    w,h=image.size
    x,y=label
    image = TF.vflip(image)
    label = x, w-y
    return image, label

# %% [markdown]
# ## Define a helper function to randomly shift or translate images ineither direction

# %%
def random_shift(image,label,max_translate=(0.2,0.2)):
    w,h=image.size
    max_t_w, max_t_h=max_translate
    cx, cy=label
    trans_coef=np.random.rand()*2-1
    w_t = int(trans_coef*max_t_w*w)
    h_t = int(trans_coef*max_t_h*h)
    image=TF.affine(image,translate=(w_t,h_t),shear=0,angle=0,scale=1)
    label = cx+w_t, cy+h_t
    return image,label

# %% [markdown]
# ## Compose multiple transformations into one function to define  transformer

# %%
import random 
def transformer(image, label, params):
    image,label=resize_img_label(image,label,params["target_size"])
    
    if random.random() < params["p_hflip"]:
        image,label=random_hflip(image,label)
        
    if random.random() < params["p_vflip"]:            
        image,label=random_vflip(image,label)
        
    if random.random() < params["p_shift"]:                            
        image,label=random_shift(image,label, params["max_translate"])
        
    image=TF.to_tensor(image)
    return image, label

# %% [markdown]
# ## Creating Custom Datasets

# %%
from torch.utils.data import Dataset
from PIL import Image

# %% [markdown]
# ## Define the bulk of the dataset class

# %%
class AMD_dataset(Dataset):
    def __init__(self, path2data, transform, trans_params):      
        pass    
      
    def __len__(self):
        # return size of dataset
        return len(self.labels)
      
    def __getitem__(self, idx):
        pass

# %% [markdown]
# ## Define the (__init__ )function

# %%
def __init__(self, path2data, transform, trans_params):      

    # read and extract labels
    self.labels = df[["x_cen","y_cen"]].values

    # extract ID and imgName columns
    self.imgName=df["image_name"]
    self.ids=df.index

    self.fullPath2img=[0]*len(self.ids)
    for id_ in self.ids:
        image_filename = pascal_voc.loc[id_, 'filename']
        self.fullPath2img[id_-1]=os.path.join(path, image_filename)

    self.transform = transform
    self.trans_params=trans_params

# %% [markdown]
# ##  Define the __getitem__ function

# %%
def __getitem__(self, idx):
    # load PIL image
    image = Image.open(self.fullPath2img[idx])  
    label= self.labels[idx]

    # transform to tensor
    image,label = self.transform(image,label,self.trans_params)

    return image, label

# %% [markdown]
# ##  Define the __getitem__ function

# %%
AMD_dataset.__init__=__init__
AMD_dataset.__getitem__=__getitem__

# %% [markdown]
# ## Define the transformation parameters for the training dataset

# %%
trans_params_train={
    "target_size" : (240, 240),
    "p_hflip" : 0.0,
    "p_vflip" : 0.0,
    "p_shift" : 0.0,
    "max_translate": (0.0, 0.0),
    "p_brightness": 0.0,
    "brightness_factor": 0.0,
    "p_contrast": 0.0,
    "contrast_factor": 0.0,
    "p_gamma": 0.0,
    "gamma": 0.0,
    "scale_label": True,    
}

# %% [markdown]
# ## Define the transformation parameters for the validation dataset

# %%
trans_params_val={
    "target_size" : (240, 240),
    "p_hflip" : 0.0,
    "p_vflip" : 0.0,
    "p_shift" : 0.0,
    "p_brightness": 0.0,
    "p_contrast": 0.0,
    "p_gamma": 0.0,
    "gamma": 0.0,
    "scale_label": True,    
}

# %% [markdown]
# ##  Two objects of the AMD_dataset class will be defined

# %%
amd_ds1=AMD_dataset(path,transformer,trans_params_train)
amd_ds2=AMD_dataset(path,transformer,trans_params_val)

# %% [markdown]
# ## Split the dataset into training and validation sets.First, we will split the image indices into two groups  mport the ShuffleSplit class from scikit-learn's model_selection module.
#
# ##### Import the ShuffleSplit class from scikit-learn's model_selection module.
#
# Create an instance of ShuffleSplit called sss with the following parameters:
#
# n_splits=1: Specifies that you want to perform a single split.
#
# test_size=0.2: Allocates 20% of the data to the validation set, while the remaining 80% will be in the training set.
#
# random_state=0: Sets the random seed for reproducibility.
#
# Create a list called indices that contains the indices of your dataset amd_ds1. Each index corresponds to a data point in your dataset.
#
# The for loop iterates over the results of the shuffle split performed by sss. In each iteration:
#
#
# train_index contains the indices of the data points in the training set.
# val_index contains the indices of the data points in the validation set.

# %%
from sklearn.model_selection import ShuffleSplit

sss = ShuffleSplit(n_splits=1, test_size=0.2, random_state=0)

indices=range(len(amd_ds1))

for train_index, val_index in sss.split(indices):
    print(len(train_index))
    print("-"*10)
    print(len(val_index))
# Out:
# 6692
# ----------
# 1674

# %% [markdown]
# ## Define the training and validation datasets

# %%
from torch.utils.data import Subset

train_ds=Subset(amd_ds1,train_index)
print(len(train_ds))

val_ds=Subset(amd_ds2,val_index)
print(len(val_ds))
# Out:
# 6692
# 1674

# %% [markdown]
# ## A sample image from train_ds and val_ds.First,  Import the required packages

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# fix random seed
np.random.seed(0)

# %% [markdown]
# ## Define a function to show a tensor image and its label
#
# #### show(img, label=None): This is the function definition. It takes two arguments: img, which is an image, and label, which is an optional label associated with the image. The label is expected to be in a specific format, as explained below.
#
# npimg = img.numpy().transpose((1,2,0)): This line converts the input img (assumed to be a tensor) into a NumPy array and transposes its dimensions. This is often done to convert the image from a format suitable for deep learning frameworks (typically channel-first) to a format suitable for Matplotlib (channel-last).
#
# plt.imshow(npimg): This line uses Matplotlib to display the image represented by npimg.
#
# if label is not None:: This conditional checks if a label has been provided as an argument. If label is not None, it means a label is associated with the image.
#
# label = rescale_label(label, img.shape[1:]): It appears that this line calls a function rescale_label to adjust the label's coordinates based on the image's shape. The exact implementation of rescale_label is not provided, but it's likely used to ensure that the label coordinates match the displayed image size.
#
# x, y = label: This line assumes that the label variable is a tuple or list containing the x and y coordinates of some points.
#
# plt.plot(x, y, 'b+', markersize=20): This line uses Matplotlib to overlay blue crosses ('b+') on the displayed image at the specified x and y coordinates. These crosses may represent points of interest or annotations associated with the image.
#
# Overall, this function is designed to display images with optional annotations (labels) as blue crosses on the image. The label coordinates are adjusted to match the displayed image size. If you have specific questions or need further assistance related to this function, please let me know.

# %%
def show(img,label=None):
    npimg = img.numpy().transpose((1,2,0))
    plt.imshow(npimg)
    if label is not None:
        label=rescale_label(label,img.shape[1:])        
        x,y=label
        plt.plot(x,y,'b+',markersize=20)

# %% [markdown]
# ##

# %%
def rescale_label(a,b):
    div = [ai*bi for ai,bi in zip(a,b)]
    return div

# %% [markdown]
# ## Show a sample image from train_ds

# %%
plt.figure(figsize=(5,5))
for img,label in train_ds:
    show(img,label)
    break

# %% [markdown]
# ## The image and its label are shown in the following screenshot

# %%
plt.figure(figsize=(5,5))
for img,label in val_ds:
    show(img,label)
    break

# %% [markdown]
# ## Define two data loaders for the training and validation datasets:
#
# #### train_dl = DataLoader(train_ds, batch_size=8, shuffle=True): This line creates a data loader for the training dataset train_ds.
#
# train_ds: This should be an instance of a PyTorch dataset, which contains your training data.
# batch_size=8: It specifies that the data loader should load the data in batches of size 8. In each iteration, the data loader will provide 8 data samples to the model.
# shuffle=True: It specifies that the data should be randomly shuffled during training. Shuffling the data helps in reducing bias during training and can improve model generalization.
# val_dl = DataLoader(val_ds, batch_size=16, shuffle=False): This line creates a data loader for the validation dataset val_ds.
#
# val_ds: This should be an instance of a PyTorch dataset containing your validation data.
# batch_size=16: It specifies that the data loader should load the data in batches of size 16 for the validation dataset.
# shuffle=False: For the validation dataset, shuffling is set to False because you typically want to evaluate the model on the validation data in a fixed order (not random order).

# %%
from torch.utils.data import DataLoader
train_dl = DataLoader(train_ds, batch_size=8, shuffle=True)
val_dl = DataLoader(val_ds, batch_size=16, shuffle=False)

# %% [markdown]
# ## Let's get a batch of data from train_dl: To get a batch, we can break the following loop after one iteration

# %%
for img_b, label_b in train_dl:
    print(img_b.shape,img_b.dtype)
    print(label_b)
    break
# Out:
# torch.Size([8, 3, 240, 240]) torch.float32
# [tensor([0.4188, 0.7104, 0.3500, 0.6687, 0.4792, 0.5687, 0.4604, 0.4021],
#        dtype=torch.float64), tensor([0.5979, 0.5563, 0.3500, 0.5917, 0.4021, 0.3521, 0.6125, 0.4229],
#        dtype=torch.float64)]

# %% [markdown]
# ## Notice that the label batch is returned as a list. Thus, we will need to convert the list to a tensor, as shown in the following code block:

# %%
import torch

# extract a batch from trainin data
for img_b, label_b in train_dl:
    print(img_b.shape,img_b.dtype)

    # convert list to tensor
    label_b=torch.stack(label_b,1)
    label_b=label_b.type(torch.float32)
    print(label_b.shape,label_b.dtype)
    break
# Out:
# torch.Size([8, 3, 240, 240]) torch.float32
# torch.Size([8, 2]) torch.float32

# %% [markdown]
# ## Similarly, we will get a batch from val_dl

# %%
for img_b, label_b in val_dl:
    print(img_b.shape,img_b.dtype)

    # convert to tensor
    label_b=torch.stack(label_b,1)
    label_b=label_b.type(torch.float32)
    print(label_b.shape,label_b.dtype)
    break
# Out:
# torch.Size([16, 3, 240, 240]) torch.float32
# torch.Size([16, 2]) torch.float32

# %% [markdown]
# # Creating A Model

# %% [markdown]
# ## Implement the model class. First, we will load the packages:

# %%
import torch.nn as nn
import torch.nn.functional as F

# %% [markdown]
# ## Define the bulk of the model class

# %%
class Net(nn.Module):
    def __init__(self, params):
        super(Net, self).__init__()
    
    def forward(self, x):
        return x

# %% [markdown]
# ## Define the __init__ function
#
#
# ### This code defines the architecture of the neural network using convolutional layers (nn.Conv2d) and fully connected layers (nn.Linear).
#
# #### This code appears to define a neural network architecture with multiple convolutional layers for feature extraction followed by a fully connected layer for classification or regression, depending on the number of output units specified in params["num_outputs"]. The actual forward pass and training logic are typically implemented in another method, usually named forward, within the same class.

# %%
def __init__(self, params):
    super(Net, self).__init__()

    C_in,H_in,W_in=params["input_shape"]
    init_f=params["initial_filters"] 
    num_outputs=params["num_outputs"] 

    self.conv1 = nn.Conv2d(C_in, init_f, kernel_size=3,stride=2,padding=1)
    self.conv2 = nn.Conv2d(init_f+C_in, 2*init_f, kernel_size=3,stride=1,padding=1)
    self.conv3 = nn.Conv2d(3*init_f+C_in, 4*init_f, kernel_size=3,padding=1)
    self.conv4 = nn.Conv2d(7*init_f+C_in, 8*init_f, kernel_size=3,padding=1)
    self.conv5 = nn.Conv2d(15*init_f+C_in, 16*init_f, kernel_size=3,padding=1)
    #self.conv5 = nn.Conv2d(15 * init_f + C_in, 240, kernel_size=3, padding=1)
    self.fc1 = nn.Linear(16*init_f, num_outputs)

# %% [markdown]
# ##  Define the forward function

# %%
def forward(self, x):
    identity=F.avg_pool2d(x,4,4)
    x = F.relu(self.conv1(x))
    x = F.max_pool2d(x, 2, 2)
    x = torch.cat((x, identity), dim=1)

    identity=F.avg_pool2d(x,2,2)
    x = F.relu(self.conv2(x))
    x = F.max_pool2d(x, 2, 2)
    x = torch.cat((x, identity), dim=1)

    identity=F.avg_pool2d(x,2,2)
    x = F.relu(self.conv3(x))
    x = F.max_pool2d(x, 2, 2)
    x = torch.cat((x, identity), dim=1)
    
    identity=F.avg_pool2d(x,2,2)
    x = F.relu(self.conv4(x))
    x = F.max_pool2d(x, 2, 2)
    x = torch.cat((x, identity), dim=1)

    x = F.relu(self.conv5(x))

    x=F.adaptive_avg_pool2d(x,1)
    x = x.reshape(x.size(0), -1)

    x = self.fc1(x)
    return x

# %% [markdown]
# ## Override the Net class functions

# %%
Net.__init__=__init__
Net.forward=forward

# %% [markdown]
# ## Define an object of the Net class

# %%
params_model={
        "input_shape": (3,240,240),
        "initial_filters": 16, 
        "num_outputs": 2,
            }

model = Net(params_model)

# %% [markdown]
# ##  We will move the model to the Compute Unified Device Architecture (CUDA) device

# %%
import torch

if torch.cuda.is_available():
    device = torch.device("cuda")
    model=model.to(device)

# %% [markdown]
# ##  We will print the model

# %%
print(model)
# Out:
# Net(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (conv2): Conv2d(19, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(51, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv4): Conv2d(115, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv5): Conv2d(243, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (fc1): Linear(in_features=256, out_features=2, bias=True)
# )

# %% [markdown]
# ## Defining Loss, Optimizer and IOU Metric

# %% [markdown]
# ## Define the loss function, optimizer, and the IOU metric. First, we will define the loss function

# %%
loss_func = nn.SmoothL1Loss(reduction="sum")

# %% [markdown]
# ## loss with known values

# %%
n,c=8,2
y = 0.5 * torch.ones(n, c, requires_grad=True)
print(y.shape)

target = torch.zeros(n, c, requires_grad=False)
print(target.shape)

loss = loss_func(y, target)
print(loss.item())

y = 2 * torch.ones(n, c, requires_grad=True)
target = torch.zeros(n, c, requires_grad=False)
loss = loss_func(y, target)
print(loss.item())
# Out:
# torch.Size([8, 2])
# torch.Size([8, 2])
# 2.0
# 24.0

# %% [markdown]
# ## Define the optimizer

# %%
from torch import optim
opt = optim.Adam(model.parameters(), lr=3e-4)

# %% [markdown]
# ## Define a helper function to read the learning rate

# %%
def get_lr(opt):
    for param_group in opt.param_groups:
        return param_group['lr']

current_lr=get_lr(opt)
print('current lr={}'.format(current_lr))
# Out:
# current lr=0.0003

# %% [markdown]
# ## Define a learning rate schedule:

# %%
from torch.optim.lr_scheduler import ReduceLROnPlateau
lr_scheduler = ReduceLROnPlateau(opt, mode='min',factor=0.5, patience=20,verbose=1)

# %% [markdown]
# ## try it out:

# %%
for i in range(100):
    lr_scheduler.step(1)
# Out:
# Epoch 00022: reducing learning rate of group 0 to 1.5000e-04.
# Epoch 00043: reducing learning rate of group 0 to 7.5000e-05.
# Epoch 00064: reducing learning rate of group 0 to 3.7500e-05.
# Epoch 00085: reducing learning rate of group 0 to 1.8750e-05.

# %% [markdown]
# ## Define a function to compute the IOU for a batch of data: First, we will define a helper function to convert coordinates to a bounding box

# %%
def cxcy2bbox(cxcy,w=40/240,h=40/240):
    # define two new tensors for w and h
    w_tensor=torch.ones(cxcy.shape[0],1,device=cxcy.device)*w
    h_tensor=torch.ones(cxcy.shape[0],1,device=cxcy.device)*h

    # extract cx and cy
    cx=cxcy[:,0].unsqueeze(1)
    cy=cxcy[:,1].unsqueeze(1)
    
    # concat cx,cy,w and h
    boxes=torch.cat((cx,cy, w_tensor, h_tensor), -1) # cx,cy,w,h
    
    return torch.cat((boxes[:, :2] - boxes[:, 2:]/2, # xmin, ymin
                     boxes[:, :2] + boxes[:, 2:]/2), 1) # xmax, ymax

# %%
torch.manual_seed(0)

cxcy=torch.rand(1,2)
print("center:", cxcy*240)

bb=cxcy2bbox(cxcy)
print("bounding box", bb*240)
# Out:
# center: tensor([[119.1016, 184.3732]])
# bounding box tensor([[ 99.1016, 164.3732, 139.1016, 204.3732]])

# %%
import torchvision
def metrics_batch(output, target):
    output=cxcy2bbox(output)
    target=cxcy2bbox(target)
    
    iou=torchvision.ops.box_iou(output, target)
    return torch.diagonal(iou, 0).sum().item()

# %%
import torch

# Check if CUDA (GPU) is available and choose the device accordingly
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

n, c = 8, 2
target = torch.rand(n, c, device=device)
# Assuming cxcy2bbox and metrics_batch are defined functions
# You can use the 'device' variable in these functions as well
target = cxcy2bbox(target)
metrics_batch(target, target)
# Out:
# 8.0

# %% [markdown]
# ## Define the loss_batch function

# %%
def loss_batch(loss_func, output, target, opt=None):   
    # get loss 
    loss = loss_func(output, target)
    
    # get performance metric
    metric_b = metrics_batch(output,target)
    
    if opt is not None:
        opt.zero_grad()
        loss.backward()
        opt.step()

    return loss.item(), metric_b

# %%
for xb,label_b in train_dl:
    # convert to tensor
    label_b=torch.stack(label_b,1)
    label_b=label_b.type(torch.float32)
    label_b=label_b.to(device)
 
    l,m=loss_batch(loss_func,label_b,label_b)
    print(l,m)
    break
# Out:
# 0.0 8.0

# %% [markdown]
# ## Training and Evaluation of the Model

# %% [markdown]
# ## Train and evaluate the model. First, we will define a loss_epoch helper function

# %%
def loss_epoch(model,loss_func,dataset_dl,sanity_check=False,opt=None):
    running_loss=0.0
    running_metric=0.0
    len_data=len(dataset_dl.dataset)

    for xb, yb in dataset_dl:
        # convert to tensor
        yb=torch.stack(yb,1)
        yb=yb.type(torch.float32).to(device)
        
        # get model output
        output=model(xb.to(device))
        
        # get loss per batch
        loss_b,metric_b=loss_batch(loss_func, output, yb, opt)
        
        # update running loss
        running_loss+=loss_b
        
        # update running metric
        if metric_b is not None:
            running_metric+=metric_b

    # average loss value
    loss=running_loss/float(len_data)
    
    # average metric value
    metric=running_metric/float(len_data)
    
    return loss, metric

# %% [markdown]
# ## Define a train_val function

# %%
import copy
def train_val(model, params):
    # extract parameters
    num_epochs=params["num_epochs"]
    loss_func=params["loss_func"]
    opt=params["optimizer"]
    train_dl=params["train_dl"]
    val_dl=params["val_dl"]
    sanity_check=params["sanity_check"]
    lr_scheduler=params["lr_scheduler"]
    path2weights=params["path2weights"]
    
    # history of loss values in each epoch
    loss_history={
        "train": [],
        "val": [],
    }
    
    # histroy of metric values in each epoch
    metric_history={
        "train": [],
        "val": [],
    }    
    
    
    # a deep copy of weights for the best performing model
    best_model_wts = copy.deepcopy(model.state_dict())
    
    # initialize best loss to a large value
    best_loss=float('inf')    
    
    for epoch in range(num_epochs):
        # get current learning rate
        current_lr=get_lr(opt)
        print('Epoch {}/{}, current lr={}'.format(epoch, num_epochs - 1, current_lr))   

        # train the model
        model.train()
        train_loss, train_metric=loss_epoch(model,loss_func,train_dl,sanity_check,opt)

        # collect loss and metric for training dataset
        loss_history["train"].append(train_loss)
        metric_history["train"].append(train_metric)
        
        # evaluate the model
        model.eval()
        with torch.no_grad():
            val_loss, val_metric=loss_epoch(model,loss_func,val_dl,sanity_check)
       
        # collect loss and metric for validation dataset
        loss_history["val"].append(val_loss)
        metric_history["val"].append(val_metric)   
        
        
        # store best model
        if val_loss < best_loss:
            best_loss = val_loss
            best_model_wts = copy.deepcopy(model.state_dict())
            
            # store weights into a local file
            torch.save(model.state_dict(), path2weights)
            print("Copied best model weights!")
            
        # learning rate schedule
        lr_scheduler.step(val_loss)
        if current_lr != get_lr(opt):
            print("Loading best model weights!")
            model.load_state_dict(best_model_wts) 
            

        print("train loss: %.6f, accuracy: %.2f" %(train_loss,100*train_metric))
        print("val loss: %.6f, accuracy: %.2f" %(val_loss,100*val_metric))
        print("-"*10) 
        

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, loss_history, metric_history

# %% [markdown]
# ## Train the model by calling the train_val function

# %%
loss_func=nn.SmoothL1Loss(reduction="sum")
opt = optim.Adam(model.parameters(), lr=1e-4)
lr_scheduler = ReduceLROnPlateau(opt, mode='min',factor=0.5, patience=20,verbose=1)

path2models= path+"models"
if not os.path.exists(path2models):
        os.mkdir(path2models)

params_train={
    "num_epochs":100,
    "optimizer": opt,
    "loss_func": loss_func,
    "train_dl": train_dl,
    "val_dl": val_dl,
    "sanity_check": False,
    "lr_scheduler": lr_scheduler,
    "path2weights": path2models+"weights_smoothl1.pt",
}

# train and validate the model
model,loss_hist,metric_hist=train_val(model,params_train)
# Out:
# Epoch 0/99, current lr=0.0001
# Copied best model weights!
# train loss: 0.019424, accuracy: 7.69
# val loss: 0.015422, accuracy: 6.82
# ----------
# Epoch 1/99, current lr=0.0001
# Copied best model weights!
# train loss: 0.014985, accuracy: 8.23
# val loss: 0.015113, accuracy: 7.10
# ----------
# Epoch 2/99, current lr=0.0001
# Copied best model weights!
# train loss: 0.014771, accuracy: 8.43
# val loss: 0.014640, accuracy: 7.66
# ----------
# Epoch 3/99, current lr=0.0001
# train loss: 0.014202, accuracy: 9.27
# val loss: 0.014645, accuracy: 8.52
# ----------
# Epoch 4/99, current lr=0.0001
# Copied best model weights!
# train loss: 0.012508, accuracy: 12.31
# val loss: 0.011358, accuracy: 15.70
# ----------
# Epoch 5/99, current lr=0.0001
# Copied best model weights!
# train loss: 0.010196, accuracy: 17.94
# val loss: 0.009468, accuracy: 20.24
# ----------
# Epoch 6/99, current lr=0.0001
# Copied best model weights!
# train loss: 0.008284, accuracy: 22.91
# ...

# %% [markdown]
# ### We will plot the training and validation loss

# %%
# Train-Validation Progress
num_epochs=params_train["num_epochs"]

# plot accuracy progress
plt.title("Train-Val Accuracy")
plt.plot(range(1,num_epochs+1),metric_hist["train"],label="train")
plt.plot(range(1,num_epochs+1),metric_hist["val"],label="val")
plt.ylabel("Accuracy")
plt.xlabel("Training Epochs")
plt.legend()
plt.show()

# %%
print("x-axis shape:", len(range(1, num_epochs + 1)))
print("train accuracy shape:", len(metric_hist["train"]))
print("validation accuracy shape:", len(metric_hist["val"]))
# Out:
# x-axis shape: 100
# train accuracy shape: 100
# validation accuracy shape: 100

# %% [markdown]
# ## Will produce the following plot

# %%
# Train-Validation Progress
num_epochs=params_train["num_epochs"]

# plot loss progress
plt.title("Train-Val Loss")
plt.plot(range(1,num_epochs+1),loss_hist["train"],label="train")
plt.plot(range(1,num_epochs+1),loss_hist["val"],label="val")
plt.ylabel("Loss")
plt.xlabel("Training Epochs")
plt.legend()
plt.show()

# %% [markdown]
# ## Deploying the Model

# %% [markdown]
# ### We will create an object of the Net class:

# %%
params_model={
 "input_shape": (3,240,240),
 "initial_filters": 16,
 "num_outputs": 2,
 }
model = Net(params_model)
model.eval()
if torch.cuda.is_available():
    device = torch.device("cuda")
    model=model.to(device)
path2weights=path2models+"weights_smoothl1.pt"
model.load_state_dict(torch.load(path2weights))
loss_func=nn.SmoothL1Loss(reduction="sum")
with torch.no_grad():
    loss,metric=loss_epoch(model,loss_func,val_dl)
print(loss,metric)
# Out:
# 0.003068675324343047 0.5061367677531362

# %%
loss_func=nn.SmoothL1Loss(reduction="sum")
with torch.no_grad():
    loss,metric=loss_epoch(model,loss_func,val_dl)
print(loss,metric)
# Out:
# 0.003068675324343047 0.5061367677531362

# %% [markdown]
# ## We will deploy the model on the image samples from val_ds. We will import the packages:

# %%
from PIL import ImageDraw
import numpy as np
import torchvision.transforms.functional as tv_F
np.random.seed(0)
import matplotlib.pylab as plt
# %matplotlib inline

# %% [markdown]
# ##  Define a function to display a tensor with two labels as bounding boxes:

# %%
def show_tensor_2labels(img,label1,label2,w_h=(50,50)):
    label1=rescale_label(label1,img.shape[1:])
    label2=rescale_label(label2,img.shape[1:])
    img=tv_F.to_pil_image(img)
    w,h=w_h
    cx,cy=label1
    draw = ImageDraw.Draw(img)
    draw.rectangle(((cx-w/2, cy-h/2), (cx+w/2,cy+h/2)),outline="green",width=2)
    cx,cy=label2
    draw.rectangle(((cx-w/2, cy-h/2), (cx+w/2,cy+h/2)),outline="red",width=2)
    plt.imshow(np.asarray(img))

# %% [markdown]
# ## Get random sample indices:

# %%
rndInds=np.random.randint(len(val_ds),size=10)
print(rndInds)
# Out:
# [ 684  559 1653 1216  835  763 1383 1033  277  599]

# %% [markdown]
# ## Next, we will deploy the model on the samples and display the predictionstogether with the ground truth

# %%
plt.rcParams['figure.figsize'] = (15, 10)
plt.subplots_adjust(wspace=0.0, hspace=0.15)
for i,rndi in enumerate(rndInds):
    img,label=val_ds[rndi]
    h,w=img.shape[1:]
    with torch.no_grad():
        label_pred=model(img.unsqueeze(0).to(device))[0].cpu()
    plt.subplot(2,3,i+1)
    show_tensor_2labels(img,label,label_pred)
 # calculate IOU
    label_bb=cxcy2bbox(torch.tensor(label).unsqueeze(0))
    label_pred_bb=cxcy2bbox(label_pred.unsqueeze(0))
    iou=torchvision.ops.box_iou(label_bb, label_pred_bb)
    plt.title("%.2f" %iou.item())
    if i>4:
        break

# %% [markdown]
# ## Next, we will Deploy the model on individual images

# %%
def load_img_label(labels_df,id_):
        imgName=labels_df["image_name"]
        image_filename = labels_df.loc[id_, 'image_name']
        fullPath2img = os.path.join(path, image_filename)
        img = Image.open(fullPath2img)
        x=labels_df["x_cen"][id_]
        y=labels_df["y_cen"][id_]
        label=(x,y)
        return img,label

# %%
labels_df=df
img,label=load_img_label(labels_df,1)
print(img.size, label)
img,label=resize_img_label(img,label,target_size=(240,240))
print(img.size, label)
img=TF.to_tensor(img)
#label=scale_label(label,(240,240))
print(img.shape)
#print(img)
with torch.no_grad():
    label_pred=model(img.unsqueeze(0).to(device))[0].cpu()
    show_tensor_2labels(img,label,label_pred)
#show(img, label_pred)
# Out:
# (240, 240) (0.4895833333333333, 0.28125)
# (240, 240) (0.48958333333333337, 0.28125)
# torch.Size([3, 240, 240])

# %% [markdown]
# ## Next, we will calculate the inference time per image

# %%
import time
elapsed_times=[]
with torch.no_grad():
    for k in range(100):
        start=time.time()
        label_pred=model(img.unsqueeze(0).to(device))[0].cpu()
        elapsed=time.time()-start
        elapsed_times.append(elapsed)
print("inference time per image: %.4f s" %np.mean(elapsed_times))
# Out:
# inference time per image: 0.0098 s
